# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 10
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=30, T=1.5, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -28.4225
# basinhopping step 1: f -28.4225 trial_f -26.5217 accepted 0  lowest_f -28.4225
# ...
# basinhopping step 2: f -26.4644 trial_f -26.4644 accepted 1  lowest_f -28.4225
# ...
# basinhopping step 3: f -27.3723 trial_f -27.3723 accepted 1  lowest_f -28.4225
# basinhopping step 4: f -27.4797 trial_f -27.4797 accepted 1  lowest_f -28.4225
# ...
# basinhopping step 5: f -26.6226 trial_f -26.6226 accepted 1  lowest_f -28.4225
# ...
# basinhopping step 6: f -26.6226 trial_f -26.5217 accepted 0  lowest_f -28.4225
# ...
# basinhopping step 7: f -27.2139 trial_f -27.2139 accepted 1  lowest_f -28.4225
# basinhopping step 8: f -27.5559 trial_f -27.5559 accepted 1  lowest_f -28.4225
# ...
# basinhopping step 9: f -27.5559 trial_f -26.4429 accepted 0  lowest_f -28.4225
# ...
# basinhopping step 10: f -28.4225 trial_f -28.4225 accepted 1  lowest_f -28.4225
# basinhopping step 11: f -28.4225 trial_f -26.4184 accepted 0  lowest_f -28.4225
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 15
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=30, T=1.5, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -46.0117
# ...
# basinhopping step 1: f -48.4504 trial_f -48.4504 accepted 1  lowest_f -48.4504
# found new global minimum on step 1 with function value -48.4504
# ...
# basinhopping step 2: f -50.4192 trial_f -50.4192 accepted 1  lowest_f -50.4192
# found new global minimum on step 2 with function value -50.4192
# ...
# basinhopping step 3: f -50.4192 trial_f -48.3268 accepted 0  lowest_f -50.4192
# ...
# basinhopping step 4: f -50.4192 trial_f -47.5412 accepted 0  lowest_f -50.4192
# ...
# basinhopping step 5: f -51.3659 trial_f -51.3659 accepted 1  lowest_f -51.3659
# found new global minimum on step 5 with function value -51.3659
# ...
# basinhopping step 6: f -51.3659 trial_f -46.3138 accepted 0  lowest_f -51.3659
# ...
# basinhopping step 7: f -51.3659 trial_f -48.3601 accepted 0  lowest_f -51.3659
# ...
# basinhopping step 8: f -51.3659 trial_f -50.2617 accepted 0  lowest_f -51.3659
# ...
# basinhopping step 9: f -51.3659 trial_f -43.0259 accepted 0  lowest_f -51.3659
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=30, T=1.5, stepsize=3.0, disp=True)
# Out:
# basinhopping step 0: f -31.4269
# basinhopping step 1: f -31.8818 trial_f -31.8818 accepted 1  lowest_f -31.8818
# found new global minimum on step 1 with function value -31.8818
# basinhopping step 2: f -31.8818 trial_f -30.5531 accepted 0  lowest_f -31.8818
# basinhopping step 3: f -31.8818 trial_f -31.1517 accepted 0  lowest_f -31.8818
# basinhopping step 4: f -31.8818 trial_f -28.9545 accepted 0  lowest_f -31.8818
# ...
# basinhopping step 5: f -30.9798 trial_f -30.9798 accepted 1  lowest_f -31.8818
# ...
# basinhopping step 6: f -29.9073 trial_f -29.9073 accepted 1  lowest_f -31.8818
# ...
# basinhopping step 7: f -30.9023 trial_f -30.9023 accepted 1  lowest_f -31.8818
# ...
# basinhopping step 8: f -31.7956 trial_f -31.7956 accepted 1  lowest_f -31.8818
# basinhopping step 9: f -31.7956 trial_f -30.9448 accepted 0  lowest_f -31.8818
# ...
# basinhopping step 10: f -31.7956 trial_f -22.1863 accepted 0  lowest_f -31.8818
# basinhopping step 11: f -29.8496 trial_f -29.8496 accepted 1  lowest_f -31.8818
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 10
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=1.5, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -26.4165
# basinhopping step 1: f -27.5559 trial_f -27.5559 accepted 1  lowest_f -27.5559
# found new global minimum on step 1 with function value -27.5559
# basinhopping step 2: f -27.5559 trial_f -27.5559 accepted 1  lowest_f -27.5559
# found new global minimum on step 2 with function value -27.5559
# ...
# basinhopping step 3: f -27.5559 trial_f -27.4797 accepted 0  lowest_f -27.5559
# ...
# basinhopping step 4: f -27.1901 trial_f -27.1901 accepted 1  lowest_f -27.5559
# basinhopping step 5: f -26.5955 trial_f -26.5955 accepted 1  lowest_f -27.5559
# basinhopping step 6: f -25.504 trial_f -25.504 accepted 1  lowest_f -27.5559
# basinhopping step 7: f -26.4429 trial_f -26.4429 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 8: f -25.552 trial_f -25.552 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 9: f -26.6233 trial_f -26.6233 accepted 1  lowest_f -27.5559
# basinhopping step 10: f -26.4429 trial_f -26.4429 accepted 1  lowest_f -27.5559
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 15
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=1.5, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -47.5293
# ...
# basinhopping step 1: f -47.5293 trial_f -45.1923 accepted 0  lowest_f -47.5293
# basinhopping step 2: f -46.5085 trial_f -46.5085 accepted 1  lowest_f -47.5293
# basinhopping step 3: f -46.5082 trial_f -46.5082 accepted 1  lowest_f -47.5293
# ...
# basinhopping step 4: f -50.4149 trial_f -50.4149 accepted 1  lowest_f -50.4149
# found new global minimum on step 4 with function value -50.4149
# ...
# basinhopping step 5: f -50.2677 trial_f -50.2677 accepted 1  lowest_f -50.4149
# ...
# basinhopping step 6: f -50.2677 trial_f -37.5413 accepted 0  lowest_f -50.4149
# ...
# basinhopping step 7: f -50.2617 trial_f -50.2617 accepted 1  lowest_f -50.4149
# ...
# basinhopping step 8: f -47.5104 trial_f -47.5104 accepted 1  lowest_f -50.4149
# ...
# basinhopping step 9: f -48.4324 trial_f -48.4324 accepted 1  lowest_f -50.4149
# ...
# basinhopping step 10: f -48.4324 trial_f -47.5295 accepted 0  lowest_f -50.4149
# ...
# basinhopping step 11: f -48.4324 trial_f -47.0984 accepted 0  lowest_f -50.4149
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=1.5, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -76.2101
# ...
# basinhopping step 1: f -76.2101 trial_f -74.796 accepted 0  lowest_f -76.2101
# ...
# basinhopping step 2: f -76.2101 trial_f -66.1141 accepted 0  lowest_f -76.2101
# ...
# basinhopping step 3: f -76.2101 trial_f -71.7377 accepted 0  lowest_f -76.2101
# ...
# basinhopping step 4: f -76.2101 trial_f -74.3227 accepted 0  lowest_f -76.2101
# ...
# basinhopping step 5: f -72.3172 trial_f -72.3172 accepted 1  lowest_f -76.2101
# ...
# basinhopping step 6: f -72.3172 trial_f -70.5208 accepted 0  lowest_f -76.2101
# ...
# basinhopping step 7: f -73.0397 trial_f -73.0397 accepted 1  lowest_f -76.2101
# ...
# basinhopping step 8: f -73.0397 trial_f -48.0481 accepted 0  lowest_f -76.2101
# ...
# basinhopping step 9: f -71.8701 trial_f -71.8701 accepted 1  lowest_f -76.2101
# ...
# basinhopping step 10: f -71.8701 trial_f -40.6738 accepted 0  lowest_f -76.2101
# ...
# basinhopping step 11: f -71.8701 trial_f -54.5347 accepted 0  lowest_f -76.2101
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 10
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=40, T=1.5, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -27.1901
# basinhopping step 1: f -27.1901 trial_f -25.3442 accepted 0  lowest_f -27.1901
# basinhopping step 2: f -27.5559 trial_f -27.5559 accepted 1  lowest_f -27.5559
# found new global minimum on step 2 with function value -27.5559
# ...
# basinhopping step 3: f -27.2139 trial_f -27.2139 accepted 1  lowest_f -27.5559
# basinhopping step 4: f -27.4797 trial_f -27.4797 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 5: f -27.5559 trial_f -27.5559 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 6: f -27.5559 trial_f -25.4075 accepted 0  lowest_f -27.5559
# ...
# basinhopping step 7: f -27.1149 trial_f -27.1149 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 8: f -27.1149 trial_f -26.4165 accepted 0  lowest_f -27.5559
# ...
# basinhopping step 9: f -27.1149 trial_f -26.558 accepted 0  lowest_f -27.5559
# ...
# basinhopping step 10: f -27.4797 trial_f -27.4797 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 11: f -27.4797 trial_f -26.558 accepted 0  lowest_f -27.5559
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 15
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=40, T=1.5, stepsize=3.0, disp=True)
# Out:
# basinhopping step 0: f -44.3239
# basinhopping step 1: f -44.3239 trial_f -41.4446 accepted 0  lowest_f -44.3239
# ...
# basinhopping step 2: f -47.2872 trial_f -47.2872 accepted 1  lowest_f -47.2872
# found new global minimum on step 2 with function value -47.2872
# ...
# basinhopping step 3: f -51.3726 trial_f -51.3726 accepted 1  lowest_f -51.3726
# found new global minimum on step 3 with function value -51.3726
# ...
# basinhopping step 4: f -51.3726 trial_f -47.4035 accepted 0  lowest_f -51.3726
# basinhopping step 5: f -52.3226 trial_f -52.3226 accepted 1  lowest_f -52.3226
# found new global minimum on step 5 with function value -52.3226
# basinhopping step 6: f -52.3226 trial_f -44.8391 accepted 0  lowest_f -52.3226
# ...
# basinhopping step 7: f -52.3226 trial_f -47.6213 accepted 0  lowest_f -52.3226
# ...
# basinhopping step 8: f -51.418 trial_f -51.418 accepted 1  lowest_f -52.3226
# ...
# basinhopping step 9: f -51.3659 trial_f -51.3659 accepted 1  lowest_f -52.3226
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=40, T=1.5, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -69.2944
# ...
# basinhopping step 1: f -71.2436 trial_f -71.2436 accepted 1  lowest_f -71.2436
# found new global minimum on step 1 with function value -71.2436
# basinhopping step 2: f -71.2436 trial_f -67.7745 accepted 0  lowest_f -71.2436
# basinhopping step 3: f -71.2436 trial_f -46.4689 accepted 0  lowest_f -71.2436
# basinhopping step 4: f -71.2436 trial_f -68.7211 accepted 0  lowest_f -71.2436
# ...
# basinhopping step 5: f -73.0394 trial_f -73.0394 accepted 1  lowest_f -73.0394
# found new global minimum on step 5 with function value -73.0394
# ...
# basinhopping step 6: f -73.0394 trial_f -68.455 accepted 0  lowest_f -73.0394
# ...
# basinhopping step 7: f -73.0394 trial_f -68.2395 accepted 0  lowest_f -73.0394
# ...
# basinhopping step 8: f -73.6216 trial_f -73.6216 accepted 1  lowest_f -73.6216
# found new global minimum on step 8 with function value -73.6216
# basinhopping step 9: f -73.6216 trial_f -70.1457 accepted 0  lowest_f -73.6216
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 10
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=1, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -27.5559
# basinhopping step 1: f -27.5559 trial_f -26.4429 accepted 0  lowest_f -27.5559
# basinhopping step 2: f -27.5452 trial_f -27.5452 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 3: f -27.5452 trial_f -26.4905 accepted 0  lowest_f -27.5559
# basinhopping step 4: f -27.5452 trial_f -27.4468 accepted 0  lowest_f -27.5559
# ...
# basinhopping step 5: f -25.4075 trial_f -25.4075 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 6: f -26.5217 trial_f -26.5217 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 7: f -28.4225 trial_f -28.4225 accepted 1  lowest_f -28.4225
# found new global minimum on step 7 with function value -28.4225
# ...
# basinhopping step 8: f -28.4225 trial_f -27.4468 accepted 0  lowest_f -28.4225
# ...
# basinhopping step 9: f -27.5559 trial_f -27.5559 accepted 1  lowest_f -28.4225
# basinhopping step 10: f -28.4225 trial_f -28.4225 accepted 1  lowest_f -28.4225
# found new global minimum on step 10 with function value -28.4225
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 15
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=1, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -28.7901
# ...
# basinhopping step 1: f -39.4448 trial_f -39.4448 accepted 1  lowest_f -39.4448
# found new global minimum on step 1 with function value -39.4448
# ...
# basinhopping step 2: f -39.4448 trial_f -38.7029 accepted 0  lowest_f -39.4448
# ...
# basinhopping step 3: f -39.1837 trial_f -39.1837 accepted 1  lowest_f -39.4448
# basinhopping step 4: f -39.4307 trial_f -39.4307 accepted 1  lowest_f -39.4448
# basinhopping step 5: f -39.4307 trial_f -37.4948 accepted 0  lowest_f -39.4448
# ...
# basinhopping step 6: f -39.4307 trial_f -37.5122 accepted 0  lowest_f -39.4448
# ...
# basinhopping step 7: f -40.7104 trial_f -40.7104 accepted 1  lowest_f -40.7104
# found new global minimum on step 7 with function value -40.7104
# ...
# basinhopping step 8: f -40.7104 trial_f -39.5371 accepted 0  lowest_f -40.7104
# ...
# basinhopping step 9: f -41.4446 trial_f -41.4446 accepted 1  lowest_f -41.4446
# found new global minimum on step 9 with function value -41.4446
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=1, stepsize=3.0, disp=True)
# Out:
# basinhopping step 0: f -61.8106
# ...
# basinhopping step 1: f -62.8728 trial_f -62.8728 accepted 1  lowest_f -62.8728
# found new global minimum on step 1 with function value -62.8728
# ...
# basinhopping step 2: f -62.8728 trial_f -59.1997 accepted 0  lowest_f -62.8728
# basinhopping step 3: f -62.8728 trial_f -54.9492 accepted 0  lowest_f -62.8728
# ...
# basinhopping step 4: f -62.8728 trial_f -58.977 accepted 0  lowest_f -62.8728
# ...
# basinhopping step 5: f -62.8749 trial_f -62.8749 accepted 1  lowest_f -62.8749
# found new global minimum on step 5 with function value -62.8749
# ...
# basinhopping step 6: f -63.4924 trial_f -63.4924 accepted 1  lowest_f -63.4924
# found new global minimum on step 6 with function value -63.4924
# ...
# basinhopping step 7: f -63.4924 trial_f -59.075 accepted 0  lowest_f -63.4924
# ...
# basinhopping step 8: f -64.905 trial_f -64.905 accepted 1  lowest_f -64.905
# found new global minimum on step 8 with function value -64.905
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 10
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=3, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -27.4468
# ...
# basinhopping step 1: f -26.4184 trial_f -26.4184 accepted 1  lowest_f -27.4468
# ...
# basinhopping step 2: f -27.1149 trial_f -27.1149 accepted 1  lowest_f -27.4468
# ...
# basinhopping step 3: f -27.5452 trial_f -27.5452 accepted 1  lowest_f -27.5452
# found new global minimum on step 3 with function value -27.5452
# basinhopping step 4: f -27.4468 trial_f -27.4468 accepted 1  lowest_f -27.5452
# ...
# basinhopping step 5: f -27.5559 trial_f -27.5559 accepted 1  lowest_f -27.5559
# found new global minimum on step 5 with function value -27.5559
# basinhopping step 6: f -26.4165 trial_f -26.4165 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 7: f -27.4797 trial_f -27.4797 accepted 1  lowest_f -27.5559
# basinhopping step 8: f -27.1149 trial_f -27.1149 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 9: f -27.5452 trial_f -27.5452 accepted 1  lowest_f -27.5559
# ...
# basinhopping step 10: f -25.1626 trial_f -25.1626 accepted 1  lowest_f -27.5559
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 15
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=3, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -30.8515
# ...
# basinhopping step 1: f -30.8874 trial_f -30.8874 accepted 1  lowest_f -30.8874
# found new global minimum on step 1 with function value -30.8874
# ...
# basinhopping step 2: f -30.8812 trial_f -30.8812 accepted 1  lowest_f -30.8874
# ...
# basinhopping step 3: f -30.8812 trial_f -30.8386 accepted 0  lowest_f -30.8874
# ...
# basinhopping step 4: f -30.9539 trial_f -30.9539 accepted 1  lowest_f -30.9539
# found new global minimum on step 4 with function value -30.9539
# ...
# basinhopping step 5: f -30.7537 trial_f -30.7537 accepted 1  lowest_f -30.9539
# basinhopping step 6: f -32.766 trial_f -32.766 accepted 1  lowest_f -32.766
# found new global minimum on step 6 with function value -32.766
# ...
# basinhopping step 7: f -30.8386 trial_f -30.8386 accepted 1  lowest_f -32.766
# ...
# basinhopping step 8: f -30.9818 trial_f -30.9818 accepted 1  lowest_f -32.766
# ...
# basinhopping step 9: f -31.7956 trial_f -31.7956 accepted 1  lowest_f -32.766
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=3, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -75.3155
# ...
# basinhopping step 1: f -75.3155 trial_f -73.6187 accepted 0  lowest_f -75.3155
# ...
# basinhopping step 2: f -75.3155 trial_f -62.3602 accepted 0  lowest_f -75.3155
# ...
# basinhopping step 3: f -72.4948 trial_f -72.4948 accepted 1  lowest_f -75.3155
# basinhopping step 4: f -71.6908 trial_f -71.6908 accepted 1  lowest_f -75.3155
# ...
# basinhopping step 5: f -71.6908 trial_f -67.9762 accepted 0  lowest_f -75.3155
# ...
# basinhopping step 6: f -71.6908 trial_f -69.6197 accepted 0  lowest_f -75.3155
# basinhopping step 7: f -69.9418 trial_f -69.9418 accepted 1  lowest_f -75.3155
# ...
# basinhopping step 8: f -72.4109 trial_f -72.4109 accepted 1  lowest_f -75.3155
# ...
# basinhopping step 9: f -67.6951 trial_f -67.6951 accepted 1  lowest_f -75.3155
# ...
# basinhopping step 10: f -68.5052 trial_f -68.5052 accepted 1  lowest_f -75.3155
# ...
# basinhopping step 11: f -67.5759 trial_f -67.5759 accepted 1  lowest_f -75.3155
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=3.5, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -43.0655
# ...
# basinhopping step 1: f -43.0655 trial_f -39.5325 accepted 0  lowest_f -43.0655
# ...
# basinhopping step 2: f -43.0093 trial_f -43.0093 accepted 1  lowest_f -43.0655
# ...
# basinhopping step 3: f -42.0175 trial_f -42.0175 accepted 1  lowest_f -43.0655
# ...
# basinhopping step 4: f -40.9556 trial_f -40.9556 accepted 1  lowest_f -43.0655
# ...
# basinhopping step 5: f -44.0085 trial_f -44.0085 accepted 1  lowest_f -44.0085
# found new global minimum on step 5 with function value -44.0085
# ...
# basinhopping step 6: f -44.0085 trial_f -41.2744 accepted 0  lowest_f -44.0085
# ...
# basinhopping step 7: f -44.0085 trial_f -40.5916 accepted 0  lowest_f -44.0085
# basinhopping step 8: f -44.0085 trial_f -41.9362 accepted 0  lowest_f -44.0085
# ...
# basinhopping step 9: f -42.3322 trial_f -42.3322 accepted 1  lowest_f -44.0085
# ...
# basinhopping step 10: f -44.0112 trial_f -44.0112 accepted 1  lowest_f -44.0112
# found new global minimum on step 10 with function value -44.0112
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=3.6, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -63.3656
# ...
# basinhopping step 1: f -59.3246 trial_f -59.3246 accepted 1  lowest_f -63.3656
# ...
# basinhopping step 2: f -62.5611 trial_f -62.5611 accepted 1  lowest_f -63.3656
# ...
# basinhopping step 3: f -61.0945 trial_f -61.0945 accepted 1  lowest_f -63.3656
# ...
# basinhopping step 4: f -61.0945 trial_f -51.3829 accepted 0  lowest_f -63.3656
# ...
# basinhopping step 5: f -61.0945 trial_f -56.3936 accepted 0  lowest_f -63.3656
# ...
# basinhopping step 6: f -62.9258 trial_f -62.9258 accepted 1  lowest_f -63.3656
# ...
# basinhopping step 7: f -62.9258 trial_f -58.3582 accepted 0  lowest_f -63.3656
# ...
# basinhopping step 8: f -65.8423 trial_f -65.8423 accepted 1  lowest_f -65.8423
# found new global minimum on step 8 with function value -65.8423
# ...
# basinhopping step 9: f -61.2842 trial_f -61.2842 accepted 1  lowest_f -65.8423
# ...
# basinhopping step 10: f -61.2842 trial_f -52.3727 accepted 0  lowest_f -65.8423
# ...
# basinhopping step 11: f -60.2983 trial_f -60.2983 accepted 1  lowest_f -65.8423
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=3, stepsize=3.7, disp=True)
# Out:
# basinhopping step 0: f -66.4499
# ...
# basinhopping step 1: f -66.9805 trial_f -66.9805 accepted 1  lowest_f -66.9805
# found new global minimum on step 1 with function value -66.9805
# ...
# basinhopping step 2: f -65.9591 trial_f -65.9591 accepted 1  lowest_f -66.9805
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-4cc2d28e2a78> in <module>()
#      26 N_atom = 20
#      27 pos = init_pos(N_atom)
# ---> 28 res = basinhopping(total_energy, pos, niter=20, T=3, stepsize=3.7, disp=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_basinhopping.py in basinhopping(func, x0, niter, T, stepsize, minimizer_kwargs, take_step, accept_test, callback, interval, disp, niter_success, seed)
#     640                " successfully"]
#     641     for i in range(niter):
# --> 642         new_global_min = bh.one_cycle()
#     643
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=20, T=3.7, stepsize=2.5, disp=True)
# Out:
# ...
# basinhopping step 0: f -49.2923
# ...
# basinhopping step 1: f -50.4373 trial_f -50.4373 accepted 1  lowest_f -50.4373
# found new global minimum on step 1 with function value -50.4373
# ...
# basinhopping step 2: f -50.4373 trial_f -41.6608 accepted 0  lowest_f -50.4373
# ...
# basinhopping step 3: f -50.018 trial_f -50.018 accepted 1  lowest_f -50.4373
# ...
# basinhopping step 4: f -53.4192 trial_f -53.4192 accepted 1  lowest_f -53.4192
# found new global minimum on step 4 with function value -53.4192
# ...
# basinhopping step 5: f -49.3621 trial_f -49.3621 accepted 1  lowest_f -53.4192
# ...
# basinhopping step 6: f -57.4751 trial_f -57.4751 accepted 1  lowest_f -57.4751
# found new global minimum on step 6 with function value -57.4751
# ...
# basinhopping step 7: f -59.3607 trial_f -59.3607 accepted 1  lowest_f -59.3607
# found new global minimum on step 7 with function value -59.3607
# basinhopping step 8: f -54.3143 trial_f -54.3143 accepted 1  lowest_f -59.3607
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=50, T=3.5, stepsize=3.0, disp=True)
# Out:
# ...
# basinhopping step 0: f -62.8064
# basinhopping step 1: f -62.8064 trial_f -60.3751 accepted 0  lowest_f -62.8064
# ...
# basinhopping step 2: f -57.6173 trial_f -57.6173 accepted 1  lowest_f -62.8064
# ...
# basinhopping step 3: f -64.8738 trial_f -64.8738 accepted 1  lowest_f -64.8738
# found new global minimum on step 3 with function value -64.8738
# ...
# basinhopping step 4: f -64.8738 trial_f -52.3226 accepted 0  lowest_f -64.8738
# ...
# basinhopping step 5: f -64.4222 trial_f -64.4222 accepted 1  lowest_f -64.8738
# ...
# basinhopping step 6: f -64.4222 trial_f -61.9053 accepted 0  lowest_f -64.8738
# ...
# basinhopping step 7: f -62.2041 trial_f -62.2041 accepted 1  lowest_f -64.8738
# ...
# basinhopping step 8: f -62.2041 trial_f -53.0144 accepted 0  lowest_f -64.8738
# basinhopping step 9: f -63.512 trial_f -63.512 accepted 1  lowest_f -64.8738
# basinhopping step 10: f -63.512 trial_f -56.2055 accepted 0  lowest_f -64.8738
# ...
# basinhopping step 11: f -65.7867 trial_f -65.7867 accepted 1  lowest_f -65.7867
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=50, T=3.7, stepsize=3.0, disp=True)
# Out:
# basinhopping step 0: f -74.6152
# ...
# basinhopping step 1: f -74.6152 trial_f -67.0331 accepted 0  lowest_f -74.6152
# ...
# basinhopping step 2: f -71.4792 trial_f -71.4792 accepted 1  lowest_f -74.6152
# ...
# basinhopping step 3: f -74.2248 trial_f -74.2248 accepted 1  lowest_f -74.6152
# ...
# basinhopping step 4: f -74.2248 trial_f -67.8225 accepted 0  lowest_f -74.6152
# ...
# basinhopping step 5: f -71.4252 trial_f -71.4252 accepted 1  lowest_f -74.6152
# ...
# basinhopping step 6: f -71.4252 trial_f -67.8344 accepted 0  lowest_f -74.6152
# ...
# basinhopping step 7: f -71.4252 trial_f -64.9391 accepted 0  lowest_f -74.6152
# basinhopping step 8: f -71.311 trial_f -71.311 accepted 1  lowest_f -74.6152
# ...
# basinhopping step 9: f -73.8526 trial_f -73.8526 accepted 1  lowest_f -74.6152
# basinhopping step 10: f -73.8526 trial_f -67.7804 accepted 0  lowest_f -74.6152
# basinhopping step 11: f -73.8526 trial_f -68.4107 accepted 0  lowest_f -74.6152
# ...

# %%
import numpy as np
#first we need to import the package that contains basin hopping
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)



def total_energy(positions):
    E = 0
    N_atom = int(len(positions)/3)
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

N_atom = 20
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=50, T=3.7, stepsize=2.5, disp=True)
# Out:
# ...
# basinhopping step 0: f -65.3871
# ...
# basinhopping step 1: f -65.6504 trial_f -65.6504 accepted 1  lowest_f -65.6504
# found new global minimum on step 1 with function value -65.6504
# ...
# basinhopping step 2: f -65.9922 trial_f -65.9922 accepted 1  lowest_f -65.9922
# found new global minimum on step 2 with function value -65.9922
# ...
# basinhopping step 3: f -68.0436 trial_f -68.0436 accepted 1  lowest_f -68.0436
# found new global minimum on step 3 with function value -68.0436
# ...
# basinhopping step 4: f -65.4629 trial_f -65.4629 accepted 1  lowest_f -68.0436
# ...
# basinhopping step 5: f -67.1511 trial_f -67.1511 accepted 1  lowest_f -68.0436
# ...
# basinhopping step 6: f -64.5559 trial_f -64.5559 accepted 1  lowest_f -68.0436
# ...
# basinhopping step 7: f -64.5559 trial_f -51.8298 accepted 0  lowest_f -68.0436
# ...
# basinhopping step 8: f -67.0416 trial_f -67.0416 accepted 1  lowest_f -68.0436
# ...
# basinhopping step 9: f -67.0416 trial_f -44.8749 accepted 0  lowest_f -68.0436
# ...
